# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data_dir = './downloads/aafcc55f646b4207ae975490e6f752ab/aafcc55f646b4207ae975490e6f752ab/data/contents/'

# %%
WY = 2010 # Water year defined as an integer
file_name = 'WY_'+str(WY)+'_UpMetN_Soil_Snow_daily.csv' # File name defined as a string
file_name
# Out:
# 'WY_2010_UpMetN_Soil_Snow_daily.csv'

# %%
df = pd.read_csv(data_dir+file_name)
df
# Out:
#       date_time   Year   Month   Day   DOY   Decimal_year   W_Year   WYD  \
# 0    10/01/2009   2009      10     1   274       0.749315     2010     1
# 1    10/02/2009   2009      10     2   275       0.752055     2010     2
# 2    10/03/2009   2009      10     3   276       0.754795     2010     3
# 3    10/04/2009   2009      10     4   277       0.757534     2010     4
# 4    10/05/2009   2009      10     5   278       0.760274     2010     5
# ..          ...    ...     ...   ...   ...            ...      ...   ...
# 360  09/26/2010   2010       9    26   269       0.735616     2010   361
# 361  09/27/2010   2010       9    27   270       0.738356     2010   362
# 362  09/28/2010   2010       9    28   271       0.741096     2010   363
# 363  09/29/2010   2010       9    29   272       0.743836     2010   364
# 364  09/30/2010   2010       9    30   273       0.746575     2010   365
#
#       Decimal_WYear   VWC Cdde10  ...    Min.64   Air_temp_Plde  deg C  \
# ...

# %%
# Print all column names
for col in df.columns:
    print(col)
# Out:
# date_time
#  Year
#  Month
#  Day
#  DOY
#  Decimal_year
#  W_Year
#  WYD
#  Decimal_WYear
#  VWC Cdde10
#   Max
#   Min
#  VWC Cduc10
#   Max.1
#   Min.1
#  VWC Acde10
#   Max.2
#   Min.2
#  VWC Acuc10
#   Max.3
#   Min.3
#  VWC Plde10
#   Max.4
#   Min.4
#  VWC Pluc10
#   Max.5
#   Min.5
#  VWC Open10
#   Max.6
#   Min.6
#  VWC Cdde30
#   Max.7
#   Min.7
#  VWC Cduc30
#   Max.8
#   Min.8
#  VWC Acde30
#   Max.9
#   Min.9
#  VWC Acuc30
#   Max.10
#   Min.10
#  VWC Plde30
#   Max.11
#   Min.11
#  VWC Pluc30
#   Max.12
#   Min.12
#  VWC Open30
#   Max.13
#   Min.13
#  VWC Cdde60
#   Max.14
#   Min.14
#  VWC Cduc60
#   Max.15
#   Min.15
#  VWC Acde60
#   Max.16
#   Min.16
#  VWC Acuc60
#   Max.17
#   Min.17
#  VWC Plde60
#   Max.18
#   Min.18
#  VWC Pluc60
#   Max.19
#   Min.19
#  VWC Open60
#   Max.20
#   Min.20
#  VWC Cduc90
#   Max.21
#   Min.21
#  VWC Acde90
#   Max.22
#   Min.22
#  VWC Acuc90
#   Max.23
#   Min.23
#  VWC Plde90
#   Max.24
#   Min.24
#  VWC Pluc90
#   Max.25
# ...

# %%
df[' VWC Cdde10'].plot()
# Out:
# <AxesSubplot:>
